# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.1
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.3     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
audit_data <- read_csv("https://raw.githubusercontent.com/luigivicencio/dsci100-003-008/main/audit_risk.csv")
trial_data <- read_csv("https://raw.githubusercontent.com/luigivicencio/dsci100-003-008/main/trial.csv")
# Out:
# New names:
# • `Score_B` -> `Score_B...7`
# • `Score_B` -> `Score_B...11`
# Rows: 776 Columns: 27
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): LOCATION_ID
# dbl (26): Sector_score, PARA_A, Score_A, Risk_A, PARA_B, Score_B...7, Risk_B...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 776 Columns: 18
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): LOCATION_ID
# dbl (17): Sector_score, PARA_A, SCORE_A, PARA_B, SCORE_B, TOTAL, numbers, Ma...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
audit_data
# Out:
#     Sector_score LOCATION_ID PARA_A Score_A Risk_A PARA_B Score_B...7 Risk_B
# 1   3.89         23           4.18  0.6     2.508   2.50  0.2          0.500
# 2   3.89         6            0.00  0.2     0.000   4.83  0.2          0.966
# 3   3.89         6            0.51  0.2     0.102   0.23  0.2          0.046
# 4   3.89         6            0.00  0.2     0.000  10.80  0.6          6.480
# 5   3.89         6            0.00  0.2     0.000   0.08  0.2          0.016
# 6   3.89         6            0.00  0.2     0.000   0.83  0.2          0.166
# 7   3.89         7            1.10  0.4     0.440   7.41  0.4          2.964
# 8   3.89         8            8.50  0.6     5.100  12.03  0.6          7.218
# 9   3.89         8            8.40  0.6     5.040  11.05  0.6          6.630
# 10  3.89         8            3.98  0.6     2.388   0.99  0.2          0.198
# 11  3.89         8            5.43  0.6     3.258  10.77  0.6          6.462
# ...

# %%
trial_data
# Out:
#     Sector_score LOCATION_ID PARA_A SCORE_A PARA_B SCORE_B TOTAL  numbers Marks
# 1   3.89         23           4.18  6        2.50  2        6.68  5.0     2
# 2   3.89         6            0.00  2        4.83  2        4.83  5.0     2
# 3   3.89         6            0.51  2        0.23  2        0.74  5.0     2
# 4   3.89         6            0.00  2       10.80  6       10.80  6.0     6
# 5   3.89         6            0.00  2        0.08  2        0.08  5.0     2
# 6   3.89         6            0.00  2        0.83  2        0.83  5.0     2
# 7   3.89         7            1.10  4        7.41  4        8.51  5.0     2
# 8   3.89         8            8.50  6       12.03  6       20.53  5.5     4
# 9   3.89         8            8.40  6       11.05  6       19.45  5.5     4
# 10  3.89         8            3.98  6        0.99  2        4.97  5.0     2
# 11  3.89         8            5.43  6       10.77  6       16.20  5.0     2
# ...
